# %%
import pytest

# %%
# !python3 -m pytest negative_test_metric.py -v
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.13.0, pytest-9.0.2, pluggy-1.6.0 -- /usr/local/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/tatiana/Desktop/Работа/Портфолио/churn_personal/test
# plugins: anyio-4.6.2.post1
# collected 5 items
#
# negative_test_metric.py::test_zero_arrays PASSED                         [ 20%]
# negative_test_metric.py::test_different_lengths PASSED                   [ 40%]
# negative_test_metric.py::test_non_numeric_input PASSED                   [ 60%]
# negative_test_metric.py::test_none_input PASSED                          [ 80%]
# negative_test_metric.py::test_inf_values PASSED                          [100%]
#
# =============================== warnings summary ===============================
# negative_test_metric.py::test_zero_arrays
#   /Users/tatiana/Desktop/Работа/Портфолио/churn_personal/src/smape_metric.py:16: RuntimeWarning: invalid value encountered in divide
# ...

# %%
# !python3 -m pytest unit_test_metric.py -v
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.13.0, pytest-9.0.2, pluggy-1.6.0 -- /usr/local/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/tatiana/Desktop/Работа/Портфолио/churn_personal/test
# plugins: anyio-4.6.2.post1
# collected 2 items
#
# unit_test_metric.py::test_smape_equal PASSED                             [ 50%]
# unit_test_metric.py::test_smape PASSED                                   [100%]
#
# ============================== 2 passed in 0.06s ===============================
